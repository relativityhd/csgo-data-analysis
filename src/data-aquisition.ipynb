# %%
import json
import os
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta
from dataclasses import dataclass, field
from typing import List

import numpy as np
import pandas as pd

import requests
from dotenv import load_dotenv
from tqdm import tqdm

load_dotenv()
# Out:
# True

# %%
headers = {"Authorization": f"Bearer {os.environ['FACEIT_API_KEY']}"}

# %% [markdown]
# ## Query Daten von FACEIT
#
# Die Statistiken aller `Matches` von einer Reihe an professionellen Spielern soll über die [FACEIT Data API](https://developers.faceit.com/docs/tools/data-api) erfasst werden.

# %% [markdown]
# Eine Liste mit Nicknamen von professionellen Spielern wurde bezogen von [CSGO Buff](https://csgobuff.pro/player/?page=5&country=all). Diese wurden Manuell in die Datei `data/professional-player-list.txt` eingetragen. Insgesamt wurden die Nicknamen von 140 professionellen Spielern erfasst.

# %%
nicknames_of_professionals = [line.strip() for line in open("../data/professional-player-list.txt").readlines()]
# Anzahl an Spielern, Die Nicknamen der ersten 5 Spieler
len(nicknames_of_professionals), nicknames_of_professionals[:5]
# Out:
# (140, ['ScreaM', 'markeloff', 'GuardiaN', 'ceh9', 'flusha'])

# %% [markdown]
# Die FACEIT Spieler IDs von den 140 Spielern werden über die [FACEIT Data API](https://developers.faceit.com/docs/tools/data-api) abgerufen.

# %%
res = []
for nickname in tqdm(nicknames_of_professionals, "Getting player information"):
    r = requests.get('https://open.faceit.com/data/v4/players', params={'nickname': nickname}, headers=headers)
    res.append(r.json())
json.dump(res, open("../data/response-professional-players.json", "w"), sort_keys=True)
# Beispiel Response vom Server
res[0]
# Out:
# Getting player information: 100%|██████████| 140/140 [00:38<00:00,  3.59it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/tobias/Repositories/csgo-data-analysis/src/data-aquisition.ipynb Cell 5' in <cell line: 5>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tobias/Repositories/csgo-data-analysis/src/data-aquisition.ipynb#ch0000003vscode-remote?line=2'>3</a>     r = requests.get('https://open.faceit.com/data/v4/players', params={'nickname': nickname}, headers=headers)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tobias/Repositories/csgo-data-analysis/src/data-aquisition.ipynb#ch0000003vscode-remote?line=3'>4</a>     res.append(r.json())
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tobias/Repositories/csgo-data-analysis/src/data-aquisition.ipynb#ch0000003vscode-remote?line=4'>5</a> json.dump(res, "../data/response-professional-players", sort_keys=True)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tobias/Repositories/csgo-data-analysis/src/data-aquisition.ipynb#ch0000003vscode-remote?line=5'>6</a> res[:5]
#
# File ~/miniconda3/envs/csgo/lib/python3.8/json/__init__.py:180, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     <a href='file:///home/tobias/miniconda3/envs/csgo/lib/python3.8/json/__init__.py?line=176'>177</a> # could accelerate with writelines in some versions of Python, at
#     <a href='file:///home/tobias/miniconda3/envs/csgo/lib/python3.8/json/__init__.py?line=177'>178</a> # a debuggability cost
#     <a href='file:///home/tobias/miniconda3/envs/csgo/lib/python3.8/json/__init__.py?line=178'>179</a> for chunk in iterable:
# --> <a href='file:///home/tobias/miniconda3/envs/csgo/lib/python3.8/json/__init__.py?line=179'>180</a>     fp.write(chunk)
#
# AttributeError: 'str' object has no attribute 'write'

# %%
# Welche Nicknamen konnten nicht gefunden werden?
infos_of_professionals = json.load(open("../data/response-professional-players.json"))
unfound = []
for i, nickname in enumerate(nicknames_of_professionals):
    r = infos_of_professionals[i]
    try:
        r['player_id']
    except KeyError:
        # Player was not found
        unfound.append(nickname)
len(unfound)
# Out:
# Getting player information: 140it [00:00, 407779.56it/s]
# 41

# %% [markdown]
# 41 Spieler konnten nicht über ihre Nicknamen gefunden werden. Dies kann verschiedene Gründe haben: Manche Spieler varieren die Schreibweise ihrer Nicknamen, so nennt sich der Spieler GuardiaN manchmal auch -GuardiaN. Ebenso sind manche Spieler bewusst unter anderem Nicknamen bei FACEIT registriert um nicht erkannt zu werden. Somit bleiben 99 professionelle Spieler für die kommende Analyse.
#
# Die Informationen zu allen Spielen aus dem letzten Jahr von den übrigen 99 spielen werden abgerufen.

# %%
infos_of_professionals = json.load(open("../data/response-professional-players.json"))
today = datetime.today()
last_year = datetime.today() - relativedelta(years=1)
res = []
for player_info in tqdm(infos_of_professionals, "Getting player match-ids"):
    try:
        player_id = player_info['player_id']
    except KeyError:
        # Player was not found
        continue
    params = {
        'game': 'csgo',
        'from': last_year.timestamp(),
        'to': today.timestamp(),
        'limit': 100
    }
    r = requests.get(f'https://open.faceit.com/data/v4/players/{player_id}/history', headers=headers, params=params)
    res.append(r.json())
json.dump(res, open("../data/response-professional-player-match_infos.json", "w"), sort_keys=True)
res[:5]
# Out:
# Getting player match-ids: 100%|██████████| 140/140 [00:00<00:00, 284635.27it/s]
# 41

# %%
match_infos = json.load(open("../data/response-professional-player-match_infos.json"))
match_ids = [match_info['match_id'] for res_info in match_infos for match_info in res_info['items']]
len(match_ids)
# Out:
# 7896

# %% [markdown]
# Es wurden 7896 Spiele gefunden. Zu diesen werden die Statistiken der

# %%
match_infos = json.load(open("../data/response-professional-player-match_infos.json"))
res = []
match_ids = [match_info['match_id'] for res_info in match_infos for match_info in res_info['items']]
for match_id in tqdm(match_ids, "Getting match stats"):
    r = requests.get(f'https://open.faceit.com/data/v4/matches/{match_id}/stats', headers=headers)
    res.append(r.json())
json.dump(res, open("../data/response-professional-player-match_stats.json", "w"), sort_keys=True)
res[:5]
# Out:
# Getting match stats: 100%|██████████| 7896/7896 [28:11<00:00,  4.67it/s]
# [{'rounds': [{'best_of': '2',
#     'competition_id': None,
#     'game_id': 'csgo',
#     'game_mode': '5v5',
#     'match_id': '1-e9647001-0a77-4c7f-84dc-a5e42df6c223',
#     'match_round': '1',
#     'played': '1',
#     'round_stats': {'Score': '16 / 9',
#      'Region': 'EU',
#      'Winner': 'a20b7fb8-b93f-4608-90af-4f1239576ea2',
#      'Rounds': '25',
#      'Map': 'de_train'},
#     'teams': [{'team_id': 'a20b7fb8-b93f-4608-90af-4f1239576ea2',
#       'premade': False,
#       'team_stats': {'Team Win': '1',
#        'Overtime score': '0',
#        'First Half Score': '8',
#        'Second Half Score': '8',
#        'Team Headshots': '10',
#        'Final Score': '16',
#        'Team': 'team_Babalicious-'},
#       'players': [{'player_id': '2a81b56b-1068-4891-b773-7f1c328a6003',
#         'nickname': 'GrandeS',
#         'player_stats': {'Triple Kills': '1',
#          'Headshots %': '53',
#          'Result': '1',
#          'K/R Ratio': '0.68',
#          'Headshots': '9',
#          'K/D Ratio': '1.21',
#          'Deaths': '14',
#          'Assists': '2',
#          'Kills': '17',
#          'Quadro Kills': '0',
#          'MVPs': '4',
#          'Penta Kills': '0'}},
#        {'player_id': '3ba5297c-7ce2-47b3-8ecd-f76a8365ab3f',
#         'nickname': 'Babalicious-',
#         'player_stats': {'Headshots': '16',
#          'Quadro Kills': '1',
#          'Headshots %': '62',
#          'K/D Ratio': '1.44',
#          'Assists': '7',
#          'Penta Kills': '0',
#          'MVPs': '2',
#          'Deaths': '18',
#          'Result': '1',
#          'Triple Kills': '2',
#          'K/R Ratio': '1.04',
#          'Kills': '26'}},
#        {'player_id': '53b13e3e-d80a-40a0-b996-a5fbe3b03db6',
#         'nickname': 'Celebrations',
#         'player_stats': {'Assists': '4',
#          'K/R Ratio': '0.6',
#          'Headshots': '4',
#          'Quadro Kills': '0',
#          'Deaths': '14',
#          'Result': '1',
#          'Kills': '15',
#          'MVPs': '2',
#          'Penta Kills': '0',
#          'Headshots %': '27',
#          'K/D Ratio': '1.07',
#          'Triple Kills': '1'}},
#        {'player_id': '90052db1-1006-4eb0-98c6-4b4fb23fbc25',
#         'nickname': 'gabex0',
#         'player_stats': {'Penta Kills': '0',
#          'Quadro Kills': '1',
#          'Result': '1',
#          'Triple Kills': '1',
#          'Headshots': '13',
#          'K/D Ratio': '2.14',
#          'Headshots %': '43',
#          'K/R Ratio': '1.2',
#          'Kills': '30',
#          'Assists': '4',
#          'Deaths': '14',
#          'MVPs': '6'}},
#        {'player_id': 'e27f770f-c743-42dd-9516-b0449e6c0ec8',
#         'nickname': 'Ekuuu',
#         'player_stats': {'Quadro Kills': '0',
#          'MVPs': '2',
#          'Triple Kills': '1',
#          'Assists': '6',
#          'Deaths': '18',
#          'K/R Ratio': '0.88',
#          'Headshots': '8',
#          'K/D Ratio': '1.22',
#          'Penta Kills': '0',
#          'Result': '1',
#          'Kills': '22',
#          'Headshots %': '36'}}]},
#      {'team_id': '9356a075-fedc-46ee-96f0-38371035e926',
#       'premade': False,
#       'team_stats': {'Second Half Score': '2',
#        'Final Score': '9',
#        'Team': 'team_ScreaM',
#        'Team Win': '0',
#        'Team Headshots': '9.2',
#        'Overtime score': '0',
#        'First Half Score': '7'},
#       'players': [{'player_id': '5a35bc70-96b6-4c47-aec1-b7363d71b29f',
#         'nickname': 'THaiz7K',
#         'player_stats': {'Headshots %': '57',
#          'Deaths': '24',
#          'K/D Ratio': '0.29',
#          'Triple Kills': '0',
#          'Headshots': '4',
#          'Penta Kills': '0',
#          'MVPs': '1',
#          'Kills': '7',
#          'Quadro Kills': '0',
#          'K/R Ratio': '0.28',
#          'Result': '0',
#          'Assists': '2'}},
#        {'player_id': 'adad8606-2c2b-4d6a-9363-74a1b9c1f656',
#         'nickname': 'makaroffzz',
#         'player_stats': {'Kills': '25',
#          'K/R Ratio': '1',
#          'Triple Kills': '1',
#          'Assists': '3',
#          'Quadro Kills': '1',
#          'Penta Kills': '0',
#          'Headshots': '11',
#          'Result': '0',
#          'Deaths': '20',
#          'Headshots %': '44',
#          'K/D Ratio': '1.25',
#          'MVPs': '3'}},
#        {'player_id': 'bf530a49-ebe0-41b1-8f80-910313ccbd98',
#         'nickname': '__OFFLINE',
#         'player_stats': {'Triple Kills': '1',
#          'Assists': '2',
#          'Penta Kills': '0',
#          'Quadro Kills': '0',
#          'MVPs': '1',
#          'Headshots': '7',
#          'Deaths': '23',
#          'K/R Ratio': '0.64',
#          'Kills': '16',
#          'Headshots %': '44',
#          'K/D Ratio': '0.7',
#          'Result': '0'}},
#        {'player_id': '546ada87-936f-4d6d-8d37-9afeb5217b1d',
#         'nickname': 'bazy-',
#         'player_stats': {'K/D Ratio': '0.29',
#          'Headshots': '7',
#          'Deaths': '24',
#          'Result': '0',
#          'Triple Kills': '0',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.28',
#          'Headshots %': '100',
#          'MVPs': '0',
#          'Assists': '3',
#          'Quadro Kills': '0',
#          'Kills': '7'}},
#        {'player_id': '9356a075-fedc-46ee-96f0-38371035e926',
#         'nickname': 'ScreaM',
#         'player_stats': {'Headshots %': '74',
#          'Result': '0',
#          'Triple Kills': '2',
#          'Penta Kills': '0',
#          'Deaths': '19',
#          'K/R Ratio': '0.92',
#          'K/D Ratio': '1.21',
#          'MVPs': '4',
#          'Assists': '0',
#          'Kills': '23',
#          'Headshots': '17',
#          'Quadro Kills': '1'}}]}]}]},
#  {'rounds': [{'best_of': '2',
#     'competition_id': None,
#     'game_id': 'csgo',
#     'game_mode': '5v5',
#     'match_id': '1-7d64cd9f-d2f8-470f-837f-a4329b4e597d',
#     'match_round': '1',
#     'played': '1',
#     'round_stats': {'Score': '16 / 9',
#      'Map': 'de_overpass',
#      'Winner': 'a6ce0e14-e428-4326-bd6b-1c95f637b914',
#      'Region': 'EU',
#      'Rounds': '25'},
#     'teams': [{'team_id': 'a6ce0e14-e428-4326-bd6b-1c95f637b914',
#       'premade': False,
#       'team_stats': {'Team': 'team_skytmegIRL',
#        'Team Win': '1',
#        'Team Headshots': '8.6',
#        'First Half Score': '8',
#        'Second Half Score': '8',
#        'Final Score': '16',
#        'Overtime score': '0'},
#       'players': [{'player_id': '34c841c4-edf6-48fe-b98c-fbae3eec7d2a',
#         'nickname': 'nastyfanboy',
#         'player_stats': {'Penta Kills': '0',
#          'Headshots %': '54',
#          'K/R Ratio': '0.96',
#          'Result': '1',
#          'Kills': '24',
#          'MVPs': '3',
#          'Triple Kills': '1',
#          'Assists': '2',
#          'Quadro Kills': '0',
#          'K/D Ratio': '1.5',
#          'Headshots': '13',
#          'Deaths': '16'}},
#        {'player_id': '614c8288-2b71-4956-bd2a-30059c93b11b',
#         'nickname': 'skytmegIRL',
#         'player_stats': {'Assists': '3',
#          'Headshots %': '65',
#          'Result': '1',
#          'Headshots': '11',
#          'Triple Kills': '1',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.68',
#          'Kills': '17',
#          'MVPs': '2',
#          'Deaths': '19',
#          'K/D Ratio': '0.89'}},
#        {'player_id': 'ad381026-708b-47a6-a61c-c14f7a5a8667',
#         'nickname': 'enviG',
#         'player_stats': {'K/D Ratio': '0.94',
#          'Headshots': '10',
#          'Kills': '16',
#          'Headshots %': '62',
#          'MVPs': '2',
#          'Penta Kills': '0',
#          'Result': '1',
#          'Deaths': '17',
#          'K/R Ratio': '0.64',
#          'Quadro Kills': '0',
#          'Triple Kills': '0',
#          'Assists': '3'}},
#        {'player_id': 'e0e02cb8-bfdf-451c-8fd2-e5d5801e4b7e',
#         'nickname': 'theNe',
#         'player_stats': {'K/R Ratio': '0.76',
#          'MVPs': '5',
#          'Result': '1',
#          'Headshots %': '32',
#          'Deaths': '16',
#          'K/D Ratio': '1.19',
#          'Penta Kills': '0',
#          'Headshots': '6',
#          'Quadro Kills': '0',
#          'Kills': '19',
#          'Triple Kills': '1',
#          'Assists': '1'}},
#        {'player_id': 'f3632afb-ab1d-41b3-82ae-699ee46baf8f',
#         'nickname': '7madara',
#         'player_stats': {'K/D Ratio': '1.4',
#          'Headshots': '3',
#          'Quadro Kills': '0',
#          'Assists': '7',
#          'Penta Kills': '0',
#          'Result': '1',
#          'MVPs': '4',
#          'Triple Kills': '0',
#          'Deaths': '15',
#          'Headshots %': '14',
#          'K/R Ratio': '0.84',
#          'Kills': '21'}}]},
#      {'team_id': 'ccb570e2-7eb5-4736-8818-55cf573d255c',
#       'premade': False,
#       'team_stats': {'Second Half Score': '2',
#        'Team Headshots': '10',
#        'Overtime score': '0',
#        'First Half Score': '7',
#        'Team': 'team_remaiN27',
#        'Team Win': '0',
#        'Final Score': '9'},
#       'players': [{'player_id': '546ada87-936f-4d6d-8d37-9afeb5217b1d',
#         'nickname': 'bazy-',
#         'player_stats': {'Assists': '1',
#          'Penta Kills': '0',
#          'K/D Ratio': '0.83',
#          'MVPs': '3',
#          'Headshots': '15',
#          'K/R Ratio': '0.6',
#          'Kills': '15',
#          'Result': '0',
#          'Deaths': '18',
#          'Triple Kills': '1',
#          'Quadro Kills': '0',
#          'Headshots %': '100'}},
#        {'player_id': '9356a075-fedc-46ee-96f0-38371035e926',
#         'nickname': 'ScreaM',
#         'player_stats': {'Headshots': '10',
#          'Penta Kills': '0',
#          'K/D Ratio': '0.75',
#          'MVPs': '1',
#          'Assists': '1',
#          'Result': '0',
#          'K/R Ratio': '0.6',
#          'Triple Kills': '0',
#          'Quadro Kills': '0',
#          'Kills': '15',
#          'Deaths': '20',
#          'Headshots %': '67'}},
#        {'player_id': '4dcdd0b3-f3b3-42bf-ae93-3c6963c112eb',
#         'nickname': 'vincso',
#         'player_stats': {'K/R Ratio': '0.68',
#          'Triple Kills': '1',
#          'Assists': '0',
#          'Result': '0',
#          'Headshots %': '53',
#          'Kills': '17',
#          'Headshots': '9',
#          'Penta Kills': '0',
#          'Deaths': '17',
#          'K/D Ratio': '1',
#          'MVPs': '2',
#          'Quadro Kills': '0'}},
#        {'player_id': '5031108a-4685-46e0-a1dc-9ce3cd939685',
#         'nickname': 'er9ko',
#         'player_stats': {'Penta Kills': '0',
#          'Headshots %': '35',
#          'K/D Ratio': '0.81',
#          'Result': '0',
#          'K/R Ratio': '0.68',
#          'Quadro Kills': '0',
#          'Headshots': '6',
#          'Kills': '17',
#          'Triple Kills': '1',
#          'MVPs': '2',
#          'Deaths': '21',
#          'Assists': '1'}},
#        {'player_id': 'ccb570e2-7eb5-4736-8818-55cf573d255c',
#         'nickname': 'remaiN27',
#         'player_stats': {'Assists': '2',
#          'Headshots %': '53',
#          'MVPs': '1',
#          'Kills': '19',
#          'Quadro Kills': '0',
#          'Headshots': '10',
#          'K/R Ratio': '0.76',
#          'K/D Ratio': '0.9',
#          'Result': '0',
#          'Penta Kills': '0',
#          'Triple Kills': '1',
#          'Deaths': '21'}}]}]}]},
#  {'rounds': [{'best_of': '2',
#     'competition_id': None,
#     'game_id': 'csgo',
#     'game_mode': '5v5',
#     'match_id': '1-22c339c2-797d-46a3-b6aa-659507a04853',
#     'match_round': '1',
#     'played': '1',
#     'round_stats': {'Score': '16 / 12',
#      'Region': 'EU',
#      'Map': 'de_mirage',
#      'Rounds': '28',
#      'Winner': '1fd4dc2b-ab74-4211-b59f-441897e8060e'},
#     'teams': [{'team_id': '1fd4dc2b-ab74-4211-b59f-441897e8060e',
#       'premade': False,
#       'team_stats': {'Overtime score': '0',
#        'First Half Score': '6',
#        'Second Half Score': '10',
#        'Team': 'team_xyusosute',
#        'Team Headshots': '13.25',
#        'Team Win': '1',
#        'Final Score': '16'},
#       'players': [{'player_id': '8c7e16ae-5d27-41fe-b3dd-c0274d6c4557',
#         'nickname': 'VULINHO',
#         'player_stats': {'Quadro Kills': '1',
#          'Assists': '2',
#          'K/R Ratio': '1',
#          'Headshots': '16',
#          'K/D Ratio': '1.56',
#          'Deaths': '18',
#          'Headshots %': '57',
#          'Result': '1',
#          'MVPs': '8',
#          'Kills': '28',
#          'Triple Kills': '4',
#          'Penta Kills': '0'}},
#        {'player_id': '546ada87-936f-4d6d-8d37-9afeb5217b1d',
#         'nickname': 'bazy-',
#         'player_stats': {'MVPs': '2',
#          'Assists': '5',
#          'K/R Ratio': '0.54',
#          'Deaths': '23',
#          'K/D Ratio': '0.65',
#          'Headshots': '11',
#          'Penta Kills': '0',
#          'Quadro Kills': '0',
#          'Kills': '15',
#          'Result': '1',
#          'Triple Kills': '1',
#          'Headshots %': '73'}},
#        {'player_id': '9356a075-fedc-46ee-96f0-38371035e926',
#         'nickname': 'ScreaM',
#         'player_stats': {'Assists': '2',
#          'Quadro Kills': '0',
#          'K/D Ratio': '1.56',
#          'MVPs': '5',
#          'Triple Kills': '5',
#          'Penta Kills': '0',
#          'Result': '1',
#          'Headshots': '23',
#          'Deaths': '18',
#          'Kills': '28',
#          'Headshots %': '82',
#          'K/R Ratio': '1'}},
#        {'player_id': 'fdbb59b2-cf06-47c6-8520-002accdd58c4',
#         'nickname': 'f0rGODen',
#         'player_stats': {'Quadro Kills': '0',
#          'K/R Ratio': '0.43',
#          'Kills': '12',
#          'Result': '1',
#          'Triple Kills': '1',
#          'Deaths': '20',
#          'Headshots': '3',
#          'K/D Ratio': '0.6',
#          'Assists': '6',
#          'Penta Kills': '0',
#          'MVPs': '0',
#          'Headshots %': '25'}}]},
#      {'team_id': 'e1bedc42-5bbc-46ae-a50d-44951c2363d4',
#       'premade': False,
#       'team_stats': {'Team Headshots': '9.2',
#        'Overtime score': '0',
#        'Second Half Score': '3',
#        'Final Score': '12',
#        'First Half Score': '9',
#        'Team': 'team_sokrf',
#        'Team Win': '0'},
#       'players': [{'player_id': '0cfddc8f-f918-44d0-a17e-3364430b2a24',
#         'nickname': 'ggsnup',
#         'player_stats': {'Kills': '31',
#          'Triple Kills': '3',
#          'Headshots': '18',
#          'Deaths': '20',
#          'Headshots %': '58',
#          'K/R Ratio': '1.11',
#          'Quadro Kills': '0',
#          'MVPs': '6',
#          'Penta Kills': '0',
#          'Result': '0',
#          'Assists': '7',
#          'K/D Ratio': '1.55'}},
#        {'player_id': '4bcda28e-622a-42e3-9297-98a0168abf5d',
#         'nickname': 'ArttuK-',
#         'player_stats': {'Penta Kills': '0',
#          'K/D Ratio': '0.87',
#          'Headshots %': '50',
#          'Headshots': '10',
#          'K/R Ratio': '0.71',
#          'Triple Kills': '0',
#          'Assists': '3',
#          'Deaths': '23',
#          'MVPs': '1',
#          'Result': '0',
#          'Quadro Kills': '1',
#          'Kills': '20'}},
#        {'player_id': '954b9b88-4a13-4eb1-a212-7baea3e45406',
#         'nickname': 'sokrf',
#         'player_stats': {'Assists': '3',
#          'Penta Kills': '0',
#          'MVPs': '1',
#          'K/D Ratio': '0.67',
#          'Headshots %': '42',
#          'Quadro Kills': '0',
#          'K/R Ratio': '0.43',
#          'Headshots': '5',
#          'Deaths': '18',
#          'Triple Kills': '0',
#          'Result': '0',
#          'Kills': '12'}},
#        {'player_id': 'e3f8ed78-79ca-4626-88c9-11389df85e08',
#         'nickname': 'ykis',
#         'player_stats': {'Deaths': '22',
#          'K/R Ratio': '0.68',
#          'Kills': '19',
#          'Headshots': '9',
#          'Assists': '2',
#          'MVPs': '4',
#          'Triple Kills': '1',
#          'Penta Kills': '0',
#          'Quadro Kills': '0',
#          'K/D Ratio': '0.86',
#          'Result': '0',
#          'Headshots %': '47'}},
#        {'player_id': 'febcb20a-bbd5-4a1f-9d74-00488d9c6242',
#         'nickname': 'manlet',
#         'player_stats': {'MVPs': '0',
#          'Result': '0',
#          'Deaths': '20',
#          'K/R Ratio': '0.5',
#          'Penta Kills': '0',
#          'Headshots': '4',
#          'Quadro Kills': '0',
#          'K/D Ratio': '0.7',
#          'Kills': '14',
#          'Headshots %': '29',
#          'Triple Kills': '0',
#          'Assists': '2'}}]}]}]},
#  {'rounds': [{'best_of': '2',
#     'competition_id': None,
#     'game_id': 'csgo',
#     'game_mode': '5v5',
#     'match_id': '1-56159af7-9a04-486e-9478-0bc10fe2cb49',
#     'match_round': '1',
#     'played': '1',
#     'round_stats': {'Score': '8 / 16',
#      'Region': 'EU',
#      'Rounds': '24',
#      'Map': 'de_mirage',
#      'Winner': '9356a075-fedc-46ee-96f0-38371035e926'},
#     'teams': [{'team_id': '7cb98b38-802f-49e3-afc0-3f4a75aec2eb',
#       'premade': False,
#       'team_stats': {'Final Score': '8',
#        'Team Win': '0',
#        'Team Headshots': '5.8',
#        'Overtime score': '0',
#        'First Half Score': '3',
#        'Second Half Score': '5',
#        'Team': 'team_shukard'},
#       'players': [{'player_id': '6c3b63f4-380d-47ef-ae45-542b1443373a',
#         'nickname': '__INSPIRE',
#         'player_stats': {'Headshots %': '54',
#          'K/R Ratio': '0.54',
#          'Headshots': '7',
#          'Kills': '13',
#          'Triple Kills': '1',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'Deaths': '20',
#          'K/D Ratio': '0.65',
#          'Result': '0',
#          'MVPs': '2',
#          'Assists': '3'}},
#        {'player_id': '09f2cede-7559-4985-a1c8-edfb01582cfc',
#         'nickname': 'Sayded',
#         'player_stats': {'MVPs': '3',
#          'K/D Ratio': '0.83',
#          'Quadro Kills': '0',
#          'Deaths': '18',
#          'Kills': '15',
#          'K/R Ratio': '0.62',
#          'Assists': '3',
#          'Headshots %': '27',
#          'Headshots': '4',
#          'Triple Kills': '1',
#          'Penta Kills': '0',
#          'Result': '0'}},
#        {'player_id': 'b7b66139-f8d6-4969-8886-bb3bcdb8056c',
#         'nickname': '--fiction',
#         'player_stats': {'Deaths': '18',
#          'K/D Ratio': '0.78',
#          'Headshots %': '43',
#          'MVPs': '0',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.58',
#          'Kills': '14',
#          'Triple Kills': '0',
#          'Assists': '4',
#          'Headshots': '6',
#          'Result': '0'}},
#        {'player_id': '01815b4a-4b1b-424b-8522-89722d226bd9',
#         'nickname': 'repobrzuszek',
#         'player_stats': {'MVPs': '0',
#          'Deaths': '22',
#          'K/R Ratio': '0.54',
#          'Penta Kills': '0',
#          'Headshots %': '54',
#          'Quadro Kills': '0',
#          'Triple Kills': '0',
#          'Headshots': '7',
#          'K/D Ratio': '0.59',
#          'Result': '0',
#          'Kills': '13',
#          'Assists': '4'}},
#        {'player_id': '7cb98b38-802f-49e3-afc0-3f4a75aec2eb',
#         'nickname': 'shukard',
#         'player_stats': {'Result': '0',
#          'K/R Ratio': '0.67',
#          'Headshots %': '31',
#          'MVPs': '3',
#          'K/D Ratio': '0.94',
#          'Assists': '3',
#          'Headshots': '5',
#          'Kills': '16',
#          'Quadro Kills': '0',
#          'Triple Kills': '1',
#          'Penta Kills': '0',
#          'Deaths': '17'}}]},
#      {'team_id': '9356a075-fedc-46ee-96f0-38371035e926',
#       'premade': False,
#       'team_stats': {'Team Win': '1',
#        'Team Headshots': '11.8',
#        'Overtime score': '0',
#        'Second Half Score': '4',
#        'Final Score': '16',
#        'First Half Score': '12',
#        'Team': 'team_ScreaM'},
#       'players': [{'player_id': 'e9f7cada-d6d5-4b43-b7a6-4c6c5072d817',
#         'nickname': 'W4LL4CEE',
#         'player_stats': {'Deaths': '14',
#          'Triple Kills': '1',
#          'Kills': '19',
#          'MVPs': '2',
#          'Result': '1',
#          'Assists': '3',
#          'Headshots %': '63',
#          'K/R Ratio': '0.79',
#          'Headshots': '12',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/D Ratio': '1.36'}},
#        {'player_id': '09879f7a-6cca-4da2-8af5-84aecb871017',
#         'nickname': 'Flick--',
#         'player_stats': {'Headshots': '10',
#          'Quadro Kills': '1',
#          'Deaths': '13',
#          'Assists': '4',
#          'MVPs': '5',
#          'Result': '1',
#          'Kills': '23',
#          'Penta Kills': '0',
#          'K/D Ratio': '1.77',
#          'Triple Kills': '0',
#          'Headshots %': '43',
#          'K/R Ratio': '0.96'}},
#        {'player_id': '7193a844-e5ef-4890-a2c9-b0b8e3b8b1bf',
#         'nickname': 'Di_Bo',
#         'player_stats': {'Headshots %': '55',
#          'Penta Kills': '1',
#          'Triple Kills': '1',
#          'Deaths': '14',
#          'K/R Ratio': '0.92',
#          'Assists': '2',
#          'Result': '1',
#          'Kills': '22',
#          'Quadro Kills': '0',
#          'Headshots': '12',
#          'K/D Ratio': '1.57',
#          'MVPs': '4'}},
#        {'player_id': '546ada87-936f-4d6d-8d37-9afeb5217b1d',
#         'nickname': 'bazy-',
#         'player_stats': {'Result': '1',
#          'Headshots': '10',
#          'K/D Ratio': '0.82',
#          'Penta Kills': '0',
#          'Kills': '14',
#          'Deaths': '17',
#          'MVPs': '2',
#          'Headshots %': '71',
#          'K/R Ratio': '0.58',
#          'Assists': '3',
#          'Quadro Kills': '1',
#          'Triple Kills': '0'}},
#        {'player_id': '9356a075-fedc-46ee-96f0-38371035e926',
#         'nickname': 'ScreaM',
#         'player_stats': {'Triple Kills': '2',
#          'Headshots %': '88',
#          'Result': '1',
#          'K/R Ratio': '0.71',
#          'Deaths': '14',
#          'MVPs': '3',
#          'Kills': '17',
#          'Assists': '4',
#          'Penta Kills': '0',
#          'Headshots': '15',
#          'Quadro Kills': '0',
#          'K/D Ratio': '1.21'}}]}]}]},
#  {'rounds': [{'best_of': '2',
#     'competition_id': None,
#     'game_id': 'csgo',
#     'game_mode': '5v5',
#     'match_id': '1-f5454bfc-3e23-47e8-b6be-2a45fd454cf2',
#     'match_round': '1',
#     'played': '1',
#     'round_stats': {'Map': 'de_inferno',
#      'Winner': 'd2513ed1-dd43-4386-8b1c-db00f0a973d3',
#      'Rounds': '24',
#      'Score': '8 / 16',
#      'Region': 'EU'},
#     'teams': [{'team_id': '9356a075-fedc-46ee-96f0-38371035e926',
#       'premade': False,
#       'team_stats': {'First Half Score': '5',
#        'Team': 'team_ScreaM',
#        'Final Score': '8',
#        'Second Half Score': '3',
#        'Team Win': '0',
#        'Team Headshots': '8.6',
#        'Overtime score': '0'},
#       'players': [{'player_id': 'e1ccb671-991b-4274-b9c7-eca8fe917382',
#         'nickname': 'CHEHOL2h',
#         'player_stats': {'K/D Ratio': '1.11',
#          'Penta Kills': '1',
#          'MVPs': '2',
#          'Result': '0',
#          'Triple Kills': '2',
#          'K/R Ratio': '0.88',
#          'Headshots %': '57',
#          'Kills': '21',
#          'Assists': '2',
#          'Deaths': '19',
#          'Headshots': '12',
#          'Quadro Kills': '0'}},
#        {'player_id': '79f0c6b7-5351-476e-8974-ef0073d694d4',
#         'nickname': 'heiNouZ',
#         'player_stats': {'Assists': '3',
#          'Deaths': '18',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.5',
#          'K/D Ratio': '0.67',
#          'MVPs': '1',
#          'Kills': '12',
#          'Headshots': '6',
#          'Result': '0',
#          'Triple Kills': '0',
#          'Headshots %': '50'}},
#        {'player_id': 'e2935d3e-dbf6-41ce-9004-1cd5fc08601e',
#         'nickname': '_corpse',
#         'player_stats': {'Result': '0',
#          'K/D Ratio': '0.72',
#          'MVPs': '1',
#          'Deaths': '18',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.54',
#          'Triple Kills': '1',
#          'Assists': '3',
#          'Headshots %': '69',
#          'Headshots': '9',
#          'Kills': '13'}},
#        {'player_id': '546ada87-936f-4d6d-8d37-9afeb5217b1d',
#         'nickname': 'bazy-',
#         'player_stats': {'Headshots %': '75',
#          'K/D Ratio': '0.19',
#          'K/R Ratio': '0.17',
#          'Quadro Kills': '0',
#          'Result': '0',
#          'Penta Kills': '0',
#          'Deaths': '21',
#          'MVPs': '0',
#          'Headshots': '3',
#          'Triple Kills': '0',
#          'Assists': '4',
#          'Kills': '4'}},
#        {'player_id': '9356a075-fedc-46ee-96f0-38371035e926',
#         'nickname': 'ScreaM',
#         'player_stats': {'Kills': '16',
#          'Headshots %': '81',
#          'Triple Kills': '2',
#          'Result': '0',
#          'Penta Kills': '0',
#          'MVPs': '4',
#          'Quadro Kills': '0',
#          'K/D Ratio': '0.89',
#          'Deaths': '18',
#          'Assists': '2',
#          'K/R Ratio': '0.67',
#          'Headshots': '13'}}]},
#      {'team_id': 'd2513ed1-dd43-4386-8b1c-db00f0a973d3',
#       'premade': False,
#       'team_stats': {'Team Win': '1',
#        'Team Headshots': '9.2',
#        'Overtime score': '0',
#        'First Half Score': '10',
#        'Team': 'team_MetaLusss',
#        'Final Score': '16',
#        'Second Half Score': '6'},
#       'players': [{'player_id': 'a5faf67f-f28a-41f4-b7f7-33b01f8eac5e',
#         'nickname': 'HippoV',
#         'player_stats': {'K/R Ratio': '0.62',
#          'MVPs': '1',
#          'Headshots': '8',
#          'Triple Kills': '0',
#          'Penta Kills': '0',
#          'Headshots %': '53',
#          'Result': '1',
#          'Deaths': '14',
#          'K/D Ratio': '1.07',
#          'Quadro Kills': '0',
#          'Kills': '15',
#          'Assists': '3'}},
#        {'player_id': 'aa168244-a5d7-4c3e-b3f9-2b21c762862e',
#         'nickname': 'LaXinho-',
#         'player_stats': {'Triple Kills': '1',
#          'Penta Kills': '0',
#          'Headshots %': '85',
#          'Kills': '13',
#          'Assists': '1',
#          'K/D Ratio': '1',
#          'Headshots': '11',
#          'MVPs': '1',
#          'Quadro Kills': '0',
#          'Deaths': '13',
#          'K/R Ratio': '0.54',
#          'Result': '1'}},
#        {'player_id': 'e4ea3b0e-7d02-40cd-ad01-7f0827ba639b',
#         'nickname': 'MetaLusss',
#         'player_stats': {'Headshots': '15',
#          'Kills': '18',
#          'Headshots %': '83',
#          'Deaths': '13',
#          'Penta Kills': '0',
#          'K/R Ratio': '0.75',
#          'Result': '1',
#          'Assists': '2',
#          'Quadro Kills': '0',
#          'Triple Kills': '1',
#          'K/D Ratio': '1.38',
#          'MVPs': '4'}},
#        {'player_id': 'ef0f813f-ec30-43af-abc5-8b740eee6bb3',
#         'nickname': 'Diviiii',
#         'player_stats': {'Deaths': '12',
#          'Headshots %': '11',
#          'Quadro Kills': '1',
#          'K/R Ratio': '1.17',
#          'Triple Kills': '2',
#          'Headshots': '3',
#          'Kills': '28',
#          'K/D Ratio': '2.33',
#          'MVPs': '7',
#          'Penta Kills': '0',
#          'Assists': '0',
#          'Result': '1'}},
#        {'player_id': 'f134c0b5-6e65-4d1a-adc4-9180ce4ce44b',
#         'nickname': 'Raznnn',
#         'player_stats': {'Triple Kills': '1',
#          'Result': '1',
#          'Quadro Kills': '0',
#          'Penta Kills': '0',
#          'K/D Ratio': '1.43',
#          'Headshots': '9',
#          'Deaths': '14',
#          'Assists': '5',
#          'Headshots %': '45',
#          'MVPs': '3',
#          'Kills': '20',
#          'K/R Ratio': '0.83'}}]}]}]}]

# %% [markdown]
# ## JSON-Responses in DataFrames konvertieren

# %%
match_stats = json.load(open("../data/response-professional-player-match_stats.json"))
len(match_stats)
# Out:
# 7896

# %% [markdown]
# `match_stats` ist eine Liste aus Dicts mit einem einzigen key: `rounds`.
# Wie viele Runden kann ein Match haben?

# %%
num_rounds_min = np.inf
num_rounds_max = 0
num_rounds_sum = 0
unfound_matches = []
for stat in match_stats:
    try:
        n = len(stat['rounds'])
    except KeyError:
        unfound_matches.append(stat)
        continue
    if n > num_rounds_max:
        num_rounds_max = n
    if n < num_rounds_min:
        num_rounds_min = n
    num_rounds_sum += n
num_rounds_mean = num_rounds_sum / len(match_stats)
num_rounds_min, num_rounds_max, num_rounds_sum, num_rounds_mean
# Out:
# (1, 4, 8312, 1.0526849037487336)

# %%
len(unfound_matches)
# Out:
# 130

# %% [markdown]
# Jedes Match hat mindestens eine Runde und maximal vier. Insgesamt hat der Datensatz 8312 Runden, diese werden einzeln behandelt. 130 von den 7896 Matches konnten nicht gefunden werden und werden ignoriert.

# %%
round_stats = [round_stat for stat in match_stats if 'rounds' in stat.keys() for round_stat in stat['rounds']]
round_keys = {}
for stat in round_stats:
    for k, v in stat.items():
        if k not in round_keys and k != 'teams':
            round_keys[k]= v
round_keys
# Out:
# {'best_of': '2',
#  'competition_id': None,
#  'game_id': 'csgo',
#  'game_mode': '5v5',
#  'match_id': '1-e9647001-0a77-4c7f-84dc-a5e42df6c223',
#  'match_round': '1',
#  'played': '1',
#  'round_stats': {'Map': 'de_train',
#   'Region': 'EU',
#   'Rounds': '25',
#   'Score': '16 / 9',
#   'Winner': 'a20b7fb8-b93f-4608-90af-4f1239576ea2'}}

# %% [markdown]
# Attribute von Interesse: `game_mode`, `round_stats`, `teams`. Entfernen aller nicht 5v5-Matches:

# %%
round_stats = [stat for stat in round_stats if stat['game_mode'] == "5v5"]
len(round_stats)
# Out:
# 8079

# %% [markdown]
# Nach entfernen der Nicht-5v5 Matches bleiben 8079 Runden. Aus diesen können nun Features zu jedem Spieler gezogen werden.

# %%
team_keys = {}
for round_stat in round_stats:
    # Define round-specific attributes / features
    for team in round_stat['teams']:
        for k, v in team.items():
            if k not in team_keys and k != 'players':
                team_keys[k] = v
team_keys
# Out:
# {'premade': False,
#  'team_id': 'a20b7fb8-b93f-4608-90af-4f1239576ea2',
#  'team_stats': {'Final Score': '16',
#   'First Half Score': '8',
#   'Overtime score': '0',
#   'Second Half Score': '8',
#   'Team': 'team_Babalicious-',
#   'Team Headshots': '10',
#   'Team Win': '1'}}

# %%
player_keys = {}
for round_stat in round_stats:
    # Define round-specific attributes / features
    for team in round_stat['teams']:
        for player in team['players']:
            for k, v in player.items():
                if k not in player_keys:
                    player_keys[k] = v
player_keys
# Out:
# {'nickname': 'GrandeS',
#  'player_id': '2a81b56b-1068-4891-b773-7f1c328a6003',
#  'player_stats': {'Assists': '2',
#   'Deaths': '14',
#   'Headshots': '9',
#   'Headshots %': '53',
#   'K/D Ratio': '1.21',
#   'K/R Ratio': '0.68',
#   'Kills': '17',
#   'MVPs': '4',
#   'Penta Kills': '0',
#   'Quadro Kills': '0',
#   'Result': '1',
#   'Triple Kills': '1'}}

# %%
player_stats = []
for round_stat in round_stats:
    # Define round-specific attributes / features
    cs_map = round_stat['round_stats']['Map']
    region = round_stat['round_stats']['Region']
    rounds_played = int(round_stat['round_stats']['Rounds'])
    winner_team_id = round_stat['round_stats']['Winner']
    round_features = {
        "Map": cs_map,
        "Region": region,
        "Rounds": rounds_played
    }
    for team in round_stat['teams']:
        is_winner = winner_team_id == team['team_id']
        premade = team['premade']
        score = int(team['team_stats']['Final Score'])
        score_first_half = int(team['team_stats']['First Half Score'])
        score_second_half = int(team['team_stats']['Second Half Score'])
        score_overtime = int(team['team_stats']['Overtime score'])
        team_features = {
            "Winner": is_winner,
            "Premade": premade,
            "Score": score,
            "Score First Half": score_first_half,
            "Score Second Half": score_second_half,
            "Score Overtime": score_overtime
        }
        for player in team['players']:
            nickname = player['nickname']
            player_id = player['player_id']
            is_professional = nickname in nicknames_of_professionals

            assists = int(player['player_stats']['Assists'])
            deaths = int(player['player_stats']['Deaths'])
            headshots = int(player['player_stats']['Headshots'])
            headshot_ratio = float(player['player_stats']['Headshots %']) / 100
            kd_ratio = float(player['player_stats']['K/D Ratio'])
            kr_ratio = float(player['player_stats']['K/R Ratio'])
            kills = int(player['player_stats']['Kills'])
            mvps = int(player['player_stats']['MVPs'])
            aces = int(player['player_stats']['Penta Kills'])
            quad = int(player['player_stats']['Quadro Kills'])
            triple = int(player['player_stats']['Triple Kills'])


            player_features = {
                "Nickname": nickname,
                "Player ID": player_id,
                "Professional": is_professional,
                "Assists": assists,
                "Deaths": deaths,
                "Headshots": headshots,
                "Headshot Ratio": headshot_ratio,
                "K/D Ratio": kd_ratio,
                "K/R Ratio": kr_ratio,
                "Kills": kills,
                "MVPs": mvps,
                "Ace": aces,
                "Quad Kills": quad,
                "Triple Kills": triple
            }

            player_stats.append(dict(
                **round_features,
                **team_features,
                **player_features
            ))
df = pd.DataFrame(player_stats)
df.to_feather("../data/player_match_statistics.feather")
df.head()
# Out:
#         Map Region  Rounds  Winner  Premade  Score  Score First Half  \
# 0  de_train     EU      25    True    False     16                 8
# 1  de_train     EU      25    True    False     16                 8
# 2  de_train     EU      25    True    False     16                 8
# 3  de_train     EU      25    True    False     16                 8
# 4  de_train     EU      25    True    False     16                 8
#
#    Score Second Half  Score Overtime      Nickname  ... Deaths  Headshots  \
# 0                  8               0       GrandeS  ...     14          9
# 1                  8               0  Babalicious-  ...     18         16
# 2                  8               0  Celebrations  ...     14          4
# 3                  8               0        gabex0  ...     14         13
# 4                  8               0         Ekuuu  ...     18          8
#
#    Headshot Ratio  K/D Ratio  K/R Ratio  Kills  MVPs  Ace  Quad Kills  \
# 0            0.53       1.21       0.68     17     4    0           0
# 1            0.62       1.44       1.04     26     2    0           1
# 2            0.27       1.07       0.60     15     2    0           0
# 3            0.43       2.14       1.20     30     6    0           1
# 4            0.36       1.22       0.88     22     2    0           0
#
#    Triple Kills
# 0             1
# 1             2
# 2             1
# 3             1
# 4             1
#
# [5 rows x 23 columns]
